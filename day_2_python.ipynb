# %%
#wap to ask ueser fav movie and store them in ist
mov=[]
mov1=input("enter movie 1:")
mov2=input("enter movie 2:")
mov3=input("enter movie 3:")
mov.append(mov1)
mov.append(mov2)
mov.append(mov3)
print(mov)
# Out:
# enter movie 1: lucy
# enter movie 2: zootopia
# enter movie 3: home alone
# ['lucy', 'zootopia', 'home alone']

# %%
#wap to check if list is palindrome 
l1=["A","B","C","B","A"]
list_copy=list.copy(l1)
list.reverse(list_copy)
if(list_copy==l1):
    print("List is palindrom:")
else:
    print("List is not palindrome:")
# Out:
# List is palindrom:

# %%
#wap to count A in tup["C","D","A","A","B","B",,"A"] AND sort them "A" to "D"

tup=("C","D","A","A","B","B","A")
tup.count("A")

list1=[]
list.append(tup)
list.sort(li)
print(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4 tup.count("A")
#       6 list1=[]
# ----> 7 list.append(tup)
#       8 list.sort(list1)
#       9 print(list1)
#
# TypeError: descriptor 'append' for 'list' objects doesn't apply to a 'tuple' object
