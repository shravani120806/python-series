# %%
#wap to find even or odd num
a=int(input("enter your no:"))
if(a%2==0):
      print("Num is even")
else:
      print("Num is odd")
# Out:
# enter your no: 24
# Num is even

# %%
#wap to find greatest of 3 nu entered

a=int(input("num1:"))
b=int(input("num2:"))
c=int(input("num3:"))
if(a>b and a>c):
    print("greatest is:",a)
elif(b>a and b>c):
    print("greatest is:",b)
else:
     print("greatest is:",c)
# Out:
# num1: 2
# num2: 3
# num3: 4
# greatest is: 4

# %%
#wap to check if no is multiple of 7 or not
a=int(input("enter your no:"))
if(a%7==0):
      print("Num is multiple of 7")
else:
      print("Num is not multiple of 7")
# Out:
# enter your no: 21
# Num is multiple of 7
