# %%
#create python dict

dict={"table":{"a piece of furniture","list of facts"},
      "cat":"a small animal"}
print(dict)
# Out:
# {'table': {'a piece of furniture', 'list of facts'}, 'cat': 'a small animal'}

# %%
subject={"python","java","c","python","java","c"}
print("Num of classroom req:",len(subject))
# Out:
# Num of classroom req: 3

# %%
dic={}
marks1=input("enter marks of chem:")
marks2=input("enter marks of phy:")
marks3=input("enter marks of maths:")
dict1={"chem":marks1,"phy":marks2,"maths":marks3}
dic.update(dict1)
print(dic)
# Out:
# enter marks of chem: 90
# enter marks of phy: 95
# enter marks of maths: 98
# {'chem': '90', 'phy': '95', 'maths': '98'}

# %%
#way to store 9 and 9.0 as different elements in set
#method1
set1={9,"9.0"}
#method2
set2={ ("fl
